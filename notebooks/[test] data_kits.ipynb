# %%
# Local directory path for the galaxy zoo 2 catalog
file_csv = '/home/hhg/Research/galaxyClassify/catalog/galaxyZoo/zoo2/gz2_all_small_v2.csv'

import sys
sys.path.append('../galaxy_generator')

# %% [markdown]
# ### ------------ start ------------

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format='retina'

from data_kits import data_split, GalaxyZooDataset, transforms_galaxy

# %%
df = pd.read_csv(file_csv)
df
# Out:
#      galaxyID  label_8  label_7  label_3
# 0           5        0        0        0
# 1           6        5        5        1
# 2           7        6        6        2
# 3           9        0        0        0
# 4          13        2        2        0
# ..        ...      ...      ...      ...
# 995      1728        3        3        1
# 996      1729        1        1        0
# 997      1732        0        0        0
# 998      1733        0        0        0
# 999      1734        0        0        0
#
# [1000 rows x 4 columns]

# %% [markdown]
# ## Test function : `data_kits.data_split`

# %%
f_train = 0.64
f_valid = 0.16
f_test  = 0.20
seed = 3

df_train, df_valid, df_test = data_split(file_csv, 
                                         f_train, f_valid, f_test, 
                                         random_state=seed, stats=True)

# %%
f_train = 0.80
f_valid = 0.20
f_test  = 0.0
seed = 3

df_train, df_valid = data_split(file_csv, 
                                f_train, f_valid, f_test, 
                                random_state=seed, stats=True)
